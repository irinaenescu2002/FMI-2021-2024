# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
x = [np.random.uniform(-1,1) for i in range(100)]
y = [i**2 for i in x]

plt.scatter(x, y)

# %%
np.corrcoef(x, y)
# Out:
# array([[1.        , 0.01338624],
#        [0.01338624, 1.        ]])

# %%
x = [np.random.uniform(-1, 1) for i in range(100)]
a = 10
b = 5
y = [a*i + b + np.random.normal() for i in x]

plt.scatter(x, y)

# %%
x = [np.random.uniform(-1, 1) for i in range(100)]
a = 10
b = 5
y = [a*i + b + np.random.normal(scale = 1) for i in x]

plt.scatter(x, y)

# %%
np.corrcoef(x, y)
# Out:
# array([[1.        , 0.98294733],
#        [0.98294733, 1.        ]])

# %%
np.quantile(x, [0.25, 0.5, 0.75, 0.99])
# Out:
# array([-0.40115289, -0.03437908,  0.46176195,  0.96240389])

# %%
x = [np.random.uniform(-1, 1) for i in range(100)]
a = 10
b = 5
y = [a*i + b + np.random.normal(scale = 10) for i in x]

plt.scatter(x, y)

# %%
np.corrcoef(x, y)
# Out:
# array([[1.        , 0.43538289],
#        [0.43538289, 1.        ]])
